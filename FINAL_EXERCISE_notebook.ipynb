# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1 style="text-align: center;"> Robots & Data Science </h1>

# %% [markdown]
# <hr>

# %% [markdown]
# <p>A robot, without the implementations of <b>data science</b>, is like a person without a personalitly.</p>

# %% [markdown]
# __Data Science Programming Languages:__
# - Python
# - R

# %% [markdown]
# __Data Science Libraries (Python):__
# - pandas
# - numpy
# - scikit-learn

# %% [markdown]
# __Data Science Tools:__
# - IBM:
#     - AutoAI
#     - Watson Digital Worker
# - Keras
# - Tensorflow

# %% [markdown]
# __Arithmetic Expression Example__

# %%
problems = 99
you = 0
reminders = 1000
how_many_problems_I_have = problems + (you * reminders)

how_many_problems_I_have
# Out:
# 99

# %% [markdown]
# __Time Function:__ Minutes to Hours Conversion

# %%
def minutes_to_hours(minutes):
    # Number of minutes in an hour
    HOUR = 60
    return minutes/HOUR

minutes_to_hours(126)
# Out:
# 2.1

# %% [markdown]
# __Objectives:__
# - Build Robots
# - Implement data science practives to improve robot behavior.
# - Distribute more functional robots

# %% [markdown]
# __Author:__ Jason R.
